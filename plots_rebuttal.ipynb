# %%
import matplotlib.pyplot as plt
import numpy as onp

# %%
n = [100, 
     250, 
     500, 
     1000, 
     2500, 
     5000, 
     10000]
n = [str(i) for i in n]  # Convert integers to strings for x-axis labels


### anm series

success_rate_anm = [
0.55,
0.53,
0.61,
0.74,
0.83,
0.86,
0.91
]
audrc_anm = [
0.5838834016813490,
0.5875180589022210,
0.7481957493092590,
0.8790878613940920,
0.9552435103067970,
0.9693708851603930,
0.9603177675383990
]

score_effect_mse_anm = [
0.25975751876831100,
0.15148614346981000,
0.08793586492538450,
0.053581226617097900,
0.02753700688481330,
0.0168231762945652,
0.0188991017639637
]

score_effect_mse_anm_low = [
0.18034306168556200,
0.10610684752464300,
0.06446067988872530,
0.03705589473247530,
0.01691385731101040,
0.012036504223942800,
0.013652628287673000
]

score_effect_mse_anm_high = [
0.3908616900444030,
0.2356245368719100,
0.1427941620349880,
0.07923348248004910,
0.03519636020064350,
0.026329971849918400,
0.053522199392318700
]


gof_causal_anm = [
0.39367878437042200,
0.3398062586784360,
0.2880910038948060,
0.22684158384800000,
0.17579306662082700,
0.1360364854335790,
0.12095041573047600
]

gof_causal_anm_low = [
0.3450789451599120,
0.285541296005249,
0.24385640025138900,
0.19487304985523200,
0.15353192389011400,
0.11978666484355900,
0.10879586637020100
]

gof_causal_anm_high = [
0.4640132188797000,
0.4042513072490690,
0.3223748803138730,
0.27035996317863500,
0.20466190576553300,
0.15663233399391200,
0.13770300149917600
]
    

gof_anticausal_anm = [
0.4197100102901460,
0.3667348623275760,
0.3100779056549070,
0.26246151328086900,
0.22086773812770800,
0.19307585060596500,
0.18611851334571800
]

gof_anticausal_anm_low = [
0.3550488352775570,
0.313748836517334,
0.26983848214149500,
0.22611835598945600,
0.1871911883354190,
0.1629381626844410,
0.15608462691307100
]

gof_anticausal_anm_high = [
0.5088598728179930,
0.41636183857917800,
0.3560868799686430,
0.3007587790489200,
0.2754996120929720,
0.23197650909423800,
0.23106849193573000
]

gof_causal_gt = [
    0.00411917082965374,
0.003194129094481470,
0.0030619511380791700,
0.0026156099047511800,
0.0026705279015004600,
0.0026222001761198000,
0.0025883575435727800
]
gof_causal_gt_low = [
0.002704216167330740,
0.002266146242618560,
0.002228609286248680,
0.0019765403121709800,
0.001737876096740370,
0.001793445786461230,
0.0019414749694988100
]

gof_causal_gt_high = [
    0.007193597964942460,
0.004730225540697580,
0.004363938234746460,
0.0040177772752940700,
0.004031440243124960,
0.0034268833696842200,
0.0037928458768874400
]

gof_anticausal_gt = [
0.5889304876327520,
0.4475400149822240,
0.39679932594299300,
0.36893054842948900,
0.3750903606414800,
0.37997347116470300,
0.3699634373188020
]

gof_anticausal_gt_low = [
0.3832187354564670,
0.31181854009628300,
0.30097514390945400,
0.29408037662506100,
0.28264540433883700,
0.27922946214675900,
0.2742519974708560
]

gof_anticausal_gt_high = [
1.041094422340390,
0.6471148729324340,
0.5756244659423830,
0.5989192128181460,
0.5745527744293210,
0.5769830346107480,
0.5709018707275390
]

idx_excl_250 = [0,2,3,4,5,6] # Exclude the second element (250) from the list
gof_causal_anm, gof_causal_anm_low, gof_causal_anm_high = onp.array(gof_causal_anm)[idx_excl_250], onp.array(gof_causal_anm_low)[idx_excl_250], onp.array(gof_causal_anm_high)[idx_excl_250]
gof_anticausal_anm, gof_anticausal_anm_low, gof_anticausal_anm_high = onp.array(gof_anticausal_anm)[idx_excl_250], onp.array(gof_anticausal_anm_low)[idx_excl_250], onp.array(gof_anticausal_anm_high)[idx_excl_250]
success_rate_anm = onp.array(success_rate_anm)[idx_excl_250]
audrc_anm = onp.array(audrc_anm)[idx_excl_250]
score_effect_mse_anm, score_effect_mse_anm_low, score_effect_mse_anm_high = onp.array(score_effect_mse_anm)[idx_excl_250], onp.array(score_effect_mse_anm_low)[idx_excl_250], onp.array(score_effect_mse_anm_high)[idx_excl_250]

gof_causal_gt, gof_causal_gt_low, gof_causal_gt_high = onp.array(gof_causal_gt)[idx_excl_250], onp.array(gof_causal_gt_low)[idx_excl_250], onp.array(gof_causal_gt_high)[idx_excl_250]
gof_anticausal_gt, gof_anticausal_gt_low, gof_anticausal_gt_high = onp.array(gof_anticausal_gt)[idx_excl_250], onp.array(gof_anticausal_gt_low)[idx_excl_250], onp.array(gof_anticausal_gt_high)[idx_excl_250]

n = [n[i] for i in idx_excl_250]  # Update n to match the indices used

# %%
def make_boxes(med, low, high):
    boxes = []
    med, low, high = onp.array(med), onp.array(low), onp.array(high)
    for i in range(len(med)):
        IQR = high[i] - low[i]
        boxes = boxes + [
            {
                'label': f"{n[i]}", 
                'whislo': low[i],
                'q1': low[i],
                'med': med[i],
                'q3': high[i],
                'whishi': high[i],
                'fliers': [],
            }
        ]
    return boxes

plt.rcParams.update({'font.size': 20})  # Adjust font size for readability

# %%
boxes_gof = make_boxes(gof_causal_anm,
                      gof_causal_anm_low, 
                      gof_causal_anm_high)

# ax1.plot(n, gof_causal_anm, color=colors[4], linestyle='-', linewidth=3)

colors = plt.cm.tab10.colors

fig, ax1 = plt.subplots(figsize=(5,5))

x = onp.array([i for i in range(len(n))])

ax1.bxp(boxes_gof, 
            vert=True, 
            patch_artist=False, 
            showfliers=False,
            boxprops=dict(color=colors[0], linewidth = 3),
            medianprops=dict(color=colors[0], linestyle="-", linewidth = 3),
            capwidths=0,
            positions = x + 0.2,
            widths = 0.3,
            zorder=0,
            label = 'Causal')

ax1.tick_params(axis='y')
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)
ax1.set_yticks([0.1, 0.3, 0.5])
ax1.set_ylim([0.0, 0.63])

boxes_gof_anticausal = make_boxes(gof_anticausal_anm, 
                      gof_anticausal_anm_low, 
                      gof_anticausal_anm_high)

# ax2 = ax1.twinx()
ax1.bxp(boxes_gof_anticausal, 
            vert=True, 
            patch_artist=False, 
            showfliers=False,
            boxprops=dict(color=colors[3], linewidth = 3, linestyle=(0, (0.5,0.5))),
            medianprops=dict(color=colors[3], linewidth = 3),
            positions = x - 0.2,
            widths = 0.3,
            capwidths=0,
            zorder=0, 
            label = 'Anticausal')

ax1.set_xticks(x)

# %%
boxes_gof = make_boxes(gof_causal_gt,
                      gof_causal_gt_low, 
                      gof_causal_gt_high)

# ax1.plot(n, gof_causal_anm, color=colors[4], linestyle='-', linewidth=3)

colors = plt.cm.tab10.colors

fig, ax1 = plt.subplots(figsize=(5,5))

x = onp.array([i for i in range(len(n))])

ax1.bxp(boxes_gof, 
            vert=True, 
            patch_artist=False, 
            showfliers=False,
            boxprops=dict(color=colors[0], linewidth = 3),
            medianprops=dict(color=colors[0], linestyle="-", linewidth = 3),
            capwidths=0,
            positions = x + 0.2,
            widths = 0.3,
            zorder=0,
            label = 'Causal')

ax1.tick_params(axis='y', length = 0)
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)
ax1.set_ylabel(r'Empirical GoF', fontsize=22)
ax1.set_ylim([0.001, 1.2])

boxes_gof_anticausal = make_boxes(gof_anticausal_gt, 
                      gof_anticausal_gt_low, 
                      gof_anticausal_gt_high)

# ax2 = ax1.twinx()
ax1.bxp(boxes_gof_anticausal, 
            vert=True, 
            patch_artist=False, 
            showfliers=False,
            boxprops=dict(color=colors[3], linewidth = 3, linestyle=(0, (0.5,0.5))),
            medianprops=dict(color=colors[3], linewidth = 3),
            positions = x - 0.2,
            widths = 0.3,
            capwidths=0,
            zorder=0, 
            label = 'Anticausal')

ax1.set_xticks(x)
ax1.set_yscale('log')

# %%
boxes_gof = make_boxes(gof_causal_anm,
                      gof_causal_anm_low, 
                      gof_causal_anm_high)

# ax1.plot(n, gof_causal_anm, color=colors[4], linestyle='-', linewidth=3)

colors = plt.cm.tab10.colors

fig, ax1 = plt.subplots(figsize=(5,5))

x = onp.array([i for i in range(len(n))])

ax1.bxp(boxes_gof, 
            vert=True, 
            patch_artist=False, 
            showfliers=False,
            boxprops=dict(color=colors[0], linewidth = 3),
            medianprops=dict(color=colors[0], linestyle="-", linewidth = 3),
            capwidths=0,
            positions = x + 0.2,
            widths = 0.3,
            zorder=0,
            label = 'Causal')

ax1.tick_params(axis='y')
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)
ax1.set_ylabel(r'Empirical GoF', fontsize=22)
ax1.set_yticks([0.1, 0.3, 0.5])
ax1.set_ylim([0.0, 0.63])

boxes_gof_anticausal = make_boxes(gof_anticausal_anm, 
                      gof_anticausal_anm_low, 
                      gof_anticausal_anm_high)

# ax2 = ax1.twinx()
ax1.bxp(boxes_gof_anticausal, 
            vert=True, 
            patch_artist=False, 
            showfliers=False,
            boxprops=dict(color=colors[3], linewidth = 3, linestyle='-'),
            medianprops=dict(color=colors[3], linestyle=(0, (0.5,0.5)), linewidth = 3),
            positions = x - 0.2,
            widths = 0.3,
            capwidths=0,
            zorder=0, 
            label = 'Anticausal')

ax1.set_xticks(x)

ax1.legend(loc='upper right', fontsize=22, ncols = 2, bbox_to_anchor = (2,2), markerscale=5)

# %%
boxes_score_mse = make_boxes(score_effect_mse_anm, score_effect_mse_anm_low, score_effect_mse_anm_high)

# ax1.plot(n, gof_causal_anm, color=colors[4], linestyle='-', linewidth=3)

colors = plt.cm.tab10.colors

fig, ax1 = plt.subplots(figsize=(5,5))

ax1.bxp(boxes_score_mse, 
            vert=True, 
            patch_artist=False, 
            showfliers=False,
            boxprops=dict(color="black", linewidth = 3),
            medianprops=dict(color="black", linestyle="-", linewidth = 3),
            positions = range(len(n)), 
            zorder=0)

ax1.tick_params(axis='y')
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)
ax1.set_ylabel(r'Score MSE', fontsize=22)
ax1.set_yticks([0.01, 0.1, 0.2, 0.3, 0.4])
ax1.set_ylim([0.0, 0.45])
# Out:
# (0.0, 0.45)

# %%
fig, ax1 = plt.subplots(figsize=(5,5))

ax1.bar(n, audrc_anm, color = colors[2], label ='AUDRC', width=0.4, zorder=1, align = 'edge', edgecolor=colors[2], linewidth=2, hatch ='/', hatch_linewidth=2, alpha=0.8)
# ax1.plot(n, audrc_anm, color=colors[2],label='AUDRC', linestyle='-', linewidth=3)
ax1.set_ylabel(r'AUDRC/Success %', fontsize=20)
ax1.tick_params(axis='y')
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)
ax1.set_yticks([0.6, 0.8, 1.0])
ax1.set_ylim([0.50, 1.02])

ax1.bar(n, success_rate_anm, color=colors[4], align = 'edge', width=-0.4, zorder=1, label='Success %', hatch='/', edgecolor=colors[4], linewidth=2, hatch_linewidth=2, alpha=0.8)
# ax1.plot(n, success_rate_anm, color=colors[4], label='Success', linestyle='--', linewidth=3)

ax1.legend(loc='upper left', fontsize=16)

# %%
# Define a colorblind-friendly palette
colors = plt.cm.tab10.colors

fig, ax1 = plt.subplots(figsize=(5, 5))

# Plot audrc_anm on the first y-axis
ax1.scatter(n, gof_causal_anm, color=colors[4], label='Causal GoF', marker = 'o', s=200)
ax1.plot(n, gof_causal_anm, color=colors[4], linestyle='-', linewidth=3)
ax1.set_xlabel('Sample Size', fontsize=22)
ax1.set_ylabel(r'Empirical GoF (o)', fontsize=22, color=colors[4])
ax1.tick_params(axis='y', labelcolor=colors[4])
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)
ax1.set_yticks([0.1, 0.3, 0.5])
ax1.set_ylim([0.0, 0.63])
# Use a different marker shape for the second axes

# Create a second y-axis for score_joint_mse_anm
ax2 = ax1.twinx()
ax2.scatter(n, score_effect_mse_anm, color=colors[3], marker = "*", label='Score Joint MSE ANM', s=300)
ax2.plot(n, score_effect_mse_anm, color=colors[3], linestyle='-', linewidth=3)
ax2.set_ylabel(r'Score MSE (*)', fontsize=22, color=colors[3])
ax2.tick_params(axis='y', labelcolor=colors[3])
ax2.set_ylim([0.0, 0.377])
ax2.set_yticks([0.01, 0.1, 0.2, 0.3])
ax2.grid(True, alpha=0.3)
# ax1.grid(False)
# ax2.grid(False)


# Add legends
# fig.tight_layout()
# plt.title('Well-specified ANM', fontsize=10)
plt.show()

# %%
plt.rcParams.update({'font.size': 18})  # Adjust font size for readability


# Define a colorblind-friendly palette
colors = plt.cm.tab10.colors

fig, ax1 = plt.subplots(figsize=(5, 5))

# Plot audrc_anm on the first y-axis
ax1.scatter(n, audrc_anm, color=colors[0], label='AUDRC ANM', marker = 'o', s=200)
ax1.plot(n, audrc_anm, color=colors[0], linestyle='-', linewidth=3)
ax1.set_xlabel('Sample Size', fontsize=20)
ax1.set_ylabel(r'AUDRC (o)', fontsize=20, color=colors[0])
ax1.tick_params(axis='y', labelcolor=colors[0])
ax1.tick_params(axis='x', rotation=45)
ax1.grid(True, alpha=0.3)
ax1.set_yticks([0.6, 0.8, 1.0])
ax1.set_ylim([0.55, 1.02])
# Use a different marker shape for the second axes

# Create a second y-axis for score_joint_mse_anm
ax2 = ax1.twinx()
ax2.scatter(n, score_effect_mse_anm, color=colors[3], marker = "*", label='Score Joint MSE ANM', s=300)
ax2.plot(n, score_effect_mse_anm, color=colors[3], linestyle='-', linewidth=3)
# ax2.set_ylabel(r'Score MSE (*)', fontsize=20, color=colors[3])
ax2.tick_params(axis='y', labelcolor=colors[3])
ax2.set_ylim([0.0, 0.377])
ax2.set_yticks([0.01, 0.1, 0.2, 0.3])
ax2.grid(True, alpha=0.3)
# ax1.grid(False)
# ax2.grid(False)


# Add legends
# fig.tight_layout()
# plt.title('Well-specified ANM', fontsize=10)
plt.show()

# %%
# Success Rate ANM

plt.rcParams.update({'font.size': 18})  # Adjust font size for readability
plt.figure(figsize=(5, 5))  # Rescale plot to fit 1/4 width of a page

# plt.scatter(n, success_rate_anm, color=colors[5], label='Success Rate')
# plt.plot(n, success_rate_anm, color=colors[5], linestyle='--')

# AUDRC ANM
plt.plot(n, gof_causal_anm, color=colors[4], linestyle='-', label = 'Causal', linewidth=4)

plt.plot(n, gof_anticausal_anm, color=colors[1], linestyle='--', label ='Anticausal', linewidth=4)

plt.xlabel('Sample Size', fontsize=20)
plt.ylabel('Empirical GoF', fontsize=20)
# plt.legend(loc='best', fontsize=20)
plt.grid(True, alpha=0.3)

# Set x-axis to log scale and add evenly spaced ticks
plt.xticks(n, labels=n)
# Define a function to format the x-axis ticks
plt.xticks(rotation=45, ha='right')
plt.grid(False)

# Show the plot
plt.tight_layout()
plt.show()

# %%
gof_causal_gt = [
0.004190811887383460,
0.0031423140317201600,
0.002957599703222510,
0.0029237321577966200,
0.0030967153143137700,
0.002983387093991040,
0.0029874336905777500]

gof_anticausal_gt = [
0.47626399993896500,
0.4184938073158260,
0.3922587037086490,
0.3834635019302370,
0.3825024962425230,
0.3769564926624300,
0.37106648087501500    
]

# %%
# Success Rate ANM

plt.rcParams.update({'font.size': 18})  # Adjust font size for readability
fig, ax1 = plt.subplots(figsize=(5, 5))  # Rescale plot to fit 1/4 width of a page

# plt.scatter(n, success_rate_anm, color=colors[5], label='Success Rate')
# plt.plot(n, success_rate_anm, color=colors[5], linestyle='--')

# AUDRC ANM

ax1.plot(n, gof_causal_gt, color=colors[4], linestyle='-', label ='Causal', linewidth=4)
ax1.set_ylim(0.0005, 0.015)
ax1.set_yticks([0.002, 0.004])
ax1.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useMathText=True)

ax1.set_xticks(n, labels=n, rotation=45, ha='right')
ax1.set_xlabel('Sample Size', fontsize=20)



ax2 = ax1.twinx()

ax2.set_ylabel('Empirical GoF', fontsize=20)


ax2.set_xlim(-0.5, len(n) - 0.5)
ax2.plot(n, gof_anticausal_gt, color=colors[1], linestyle='--', label = 'Anticausal', linewidth=4)
ax2.set_xlabel('Sample Size', fontsize=20)

# Set x-axis to log scale and add evenly spaced ticks
ax2.grid(False)
ax2.set_ylim(0.1, 0.6)
ax2.set_yticks([0.4, 0.5])
ax2.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useMathText=True)

ax2.hlines([0.3], xmin=-1, xmax=len(n), color='grey', linestyle='--', linewidth=1, alpha = 0.5)


## making a scale for the y axis 

plt.tight_layout()


# import numpy as onp

# def forward(x):
#     return onp.where(x < 0.02, x**(1/5), x)


# def inverse(y):
#     return onp.where(y < 0.02**(1/4), y**5, y)

# # Show the plot
# ax.set_ylim(0.002, 0.6)
# ax.set_yscale('function', functions=(forward, inverse))
# # ax.set_yscale('log', base = 2)
# ax.set_yticks([0.003, 0.005, 0.4, 0.5])
# plt.show()

# %%
from mechanisms import mechanism_from_flow
from plotting import plot_velocity_grid
import jax.numpy as jnp
import jax


class estimated_flow(mechanism_from_flow):

    def __init__(self, model, params):
        super().__init__(stiff = False)
        self.model = model
        self.params = params

    def velocity(self, y, x):
        return self.model(y, x, self.params)
    
from mechanisms import flow_from_mechanism

class nn_conditioner_mechanism(flow_from_mechanism):

    def __init__(self, mech = "anm", **kwargs):
        super().__init__()
        self.mech = mech
        if mech == "anm":
            n_out = 1
        elif mech == "lsnm":
            n_out = 2
        else:
            n_out = 0
        self.build_nn_params(n_out, **kwargs)


    def build_nn_params(self, n_out, layers = 3, hidden_size = 64, seed = 0, init_weight = 0.4):
        params = {"w1": jax.random.normal(shape=(1, hidden_size), key=jax.random.PRNGKey(seed))*init_weight,
                    "b1": jax.random.normal(shape=(hidden_size), key=jax.random.PRNGKey(seed + 1))*init_weight}
        for i in range(layers - 2):
            params[f"w{i+2}"] = jax.random.normal(shape=(hidden_size, hidden_size), key=jax.random.PRNGKey(seed))*init_weight
            params[f"b{i+2}"] = jax.random.normal(shape=(hidden_size), key=jax.random.PRNGKey(seed + 1))*init_weight
            seed = seed + 2
        params[f"w{layers}"] = jax.random.normal(shape=(hidden_size, n_out), key=jax.random.PRNGKey(seed))*init_weight
        params[f"b{layers}"] = jax.random.normal(shape=(n_out), key=jax.random.PRNGKey(seed + 1))*init_weight
        self.params = params
        self.layers = layers

    def nn_conditioner(self, x):
        x = jnp.array(x)
        if x.ndim == 1:
            x = x[:, None]
        h = x
        for i in range(self.layers-1):
            h = jnp.dot(h, self.params[f"w{i+1}"]) + self.params[f"b{i+1}"]
            h = jax.nn.tanh(h)
        out = jnp.dot(h, self.params[f"w{self.layers}"]) + self.params[f"b{self.layers}"]
        return out

    def forward(self, x, e):
        """
        compute y = f_{x}(e)
        """
        cond = self.nn_conditioner(x)
        if self.mech == "anm":
            return (e + cond.squeeze()).squeeze()
        elif self.mech == "lsnm":
            mu, sigma = cond[:, 0], jnp.exp(cond[:, 1])
            return (mu + (sigma+0.1) * e).squeeze()
        elif self.mech == "exp":
            return jnp.exp(x + e).squeeze()

    def inverse(self, x, y):
        """
        compute e = f^{-1}_x(y) 
        """
        cond = self.nn_conditioner(x)
        if self.mech == "anm":
            return (y - cond.squeeze()).squeeze()
        elif self.mech == "lsnm":
            mu, sigma = cond[:, 0], jnp.exp(cond[:, 1])
            return ((y - mu)/(sigma+0.1)).squeeze()
        elif self.mech == "exp":
            return (jnp.log(y) - x).squeeze()

        
model = nn_conditioner_mechanism(mech = "exp", seed = 1, layers = 2, hidden_size = 4, init_weight = 2)

# %%
fig, ax = plt.subplots(figsize=(8, 3))

x = jnp.linspace(1,5, 1000)
# y = jnp.exp(x**1.2)
y = model.forward(x, jnp.zeros_like(x))
# y1 = model.forward(x, jnp.ones_like(x))
# y2 = model.forward(x, -jnp.ones_like(x))

curve = ax.plot(x, y, color='blue', linewidth=3, label = r'$\epsilon\in \{0, \pm 1\}$')
# ax.plot(x, y1, color='blue', linewidth=3)
# ax.plot(x, y2, color='blue', linewidth=3)

# Add gridlines
# ax.grid(True, which='major', linestyle='--', linewidth=1, axis = "y")
# ax.grid(True, which='both', linestyle='--', linewidth=1, axis = "x")

# Customize the tick marks
ax.minorticks_on()
ax.tick_params(which='both', direction='in', top=False, right=False)
ax.tick_params(which='major', length=0)
ax.tick_params(which='minor', length=0)
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_xlabel('')
ax.set_ylabel('')

plot_velocity_grid(jax.vmap(model.velocity, in_axes = (0,0)), n_pts = 15)

# X, Y = jnp.meshgrid(jnp.arange(x_min, x_max, (x_max-x_min)/n_pts), jnp.arange(y_min, y_max, (y_max - y_min)/n_pts))
# v_yt = jax.vmap(jax.vmap(m.velocity, in_axes = (0,0)), in_axes = (0, 0))
# U = jnp.ones_like(X)
# V = v_yt(Y, X).squeeze()
# magnitude = jnp.sqrt(U**2 + V**2)
# U, V = U/magnitude, V/magnitude
# ax.legend(fontsize=30, markerscale=4, framealpha=1)

for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)

# %%
anm = nn_conditioner_mechanism(mech = "anm", seed = 7, layers = 3, hidden_size = 32, init_weight = 0.4)
n = 100
fig, ax = plt.subplots(figsize=(6,6))

from plotting import plot_data, plot_flow 

x_data = jnp.zeros((n,))
y_data = jax.random.normal(key=jax.random.PRNGKey(0), shape = (n,)) * 0.5

# plot_data(x_data, y_data, alpha = 0.8)
plot_flow(anm.flow,
           x_init = x_data,
           y_init = y_data, 
           xlim = (-2, 2),
          n_pts = 1000,
          color = "blue", 
          alpha = 0.3)
plt.ylim(-3, 3)
plot_velocity_grid(jax.vmap(anm.velocity), n_pts = 10, alpha = 0.5)

ax.tick_params(which='both', direction='in', top=False, right=False)
ax.tick_params(which='major', length=0)
ax.tick_params(which='minor', length=0)
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_xlabel('')
ax.set_ylabel('')

for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)

# %%
lsnm = nn_conditioner_mechanism(mech = "lsnm", seed = 0, layers = 2, hidden_size = 32, init_weight = 0.3)
n = 100
fig, ax = plt.subplots(figsize=(6,6))

from plotting import plot_data, plot_flow 

x_data = jnp.zeros((n,))
y_data = jax.random.normal(key=jax.random.PRNGKey(0), shape = (n,)) * 0.5

# plot_data(x_data, y_data, alpha = 0.8)
plt.xlim(-2, 1)
plot_flow(lsnm.flow,
           x_init = x_data,
           y_init = y_data, 
           xlim = (-2, 1),
          n_pts = 1000,
          color = "blue", 
          alpha = 0.3)
plt.ylim(-3, 3)
plot_velocity_grid(jax.vmap(lsnm.velocity), n_pts = 10, alpha = 0.5)


ax.tick_params(which='both', direction='in', top=False, right=False)
ax.tick_params(which='major', length=0)
ax.tick_params(which='minor', length=0)
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_xlabel('')
ax.set_ylabel('')

for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)

# %%
from mechanisms import mechanism_from_flow

class estimated_flow(mechanism_from_flow):

    def __init__(self):
        super().__init__(stiff = True)

    def velocity(self, y, x):
        return jnp.exp(-y**2)
    
model = estimated_flow()

n = 100
fig, ax = plt.subplots(figsize=(6,6))

from plotting import plot_data, plot_flow 

x_data = jnp.zeros((n,))
y_data = jax.random.normal(key=jax.random.PRNGKey(0), shape = (n,)) * 0.5
# y_data.at[50:].set( 0.5 * y_data[50:] + 2)
# y_data.at[:50].set( 0.5 * y_data[:50] - 2)

# plot_data(x_data, y_data, alpha = 0.8)
plt.xlim(-2, 2)
plot_flow(model.flow,
           x_init = x_data,
           y_init = y_data, 
           xlim = (-2, 2),
          n_pts = 1000,
          color = "blue", 
          alpha = 0.3)
plt.ylim(-3, 3)
plot_velocity_grid(jax.vmap(model.velocity), n_pts = 10, alpha = 0.5)


ax.tick_params(which='both', direction='in', top=False, right=False)
ax.tick_params(which='major', length=0)
ax.tick_params(which='minor', length=0)
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_xlabel('')
ax.set_ylabel('')


for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)

# %%
from mpl_toolkits.mplot3d import Axes3D

x = jnp.linspace(-3, 3, 1000)
from jax.scipy.stats.norm import pdf 
y = pdf(x, loc=0, scale=1.5)
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection="3d")
ax.plot(xs = x, ys = jnp.zeros_like(x), zs = y, color='red', linewidth=5, label = r'$p_Y(y)$')

ax.grid(False)
ax.tick_params(which='both', direction='in', top=False, right=False)
ax.tick_params(which='major', length=0)
ax.tick_params(which='minor', length=0)
ax.set_axis_off()
# ax.set_xticklabels([])
# ax.set_yticklabels([])
# ax.set_xlabel('')
# ax.set_ylabel('')
# ax.set_zticklabels([])
# ax.set_zticklabels([])
# ax.set_zlabel('')
# ax.set_zlabel('')

# %%
import matplotlib.pyplot

def gauss1(x):
    return np.exp(-(x**2))

def gauss(x, y):
    return gauss1(x)*gauss1(2*y)

fig = plt.figure()
ax = fig.gca(projection='3d')
x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
Z = gauss(X, Y)

ax.plot_surface(X, Y, Z, rstride=2, cstride=2, alpha=0.4, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='x', offset=-4, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='y', offset=4, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[280], line 13
#      10     return gauss1(x)*gauss1(2*y)
#      12 fig = plt.figure()
# ---> 13 ax = fig.gca(projection='3d')
#      14 x = np.linspace(-3, 3, 100)
#      15 y = np.linspace(-3, 3, 100)
#
# TypeError: FigureBase.gca() got an unexpected keyword argument 'projection'
